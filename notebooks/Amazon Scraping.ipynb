# %% [markdown]
# ## Amazon Best Sellers Book Links
# https://www.amazon.com/best-sellers-books-Amazon/zgbs/books
# https://www.amazon.com/best-sellers-books-Amazon/zgbs/books/ref=zg_bs_pg_2?_encoding=UTF8&pg=2

# %% [markdown]
# ## 1. Import libraries

# %%
import requests as rq
import pandas as pd
from bs4 import BeautifulSoup as bs
import lxml
import re

# %% [markdown]
# ## 2. Set base urls

# %%
url1 = 'https://www.amazon.com/best-sellers-books-Amazon/zgbs/books'
url2 = 'https://www.amazon.com/best-sellers-books-Amazon/zgbs/books/ref=zg_bs_pg_2?_encoding=UTF8&pg=2'

# %% [markdown]
# ## 3. Make a request

# %%
# set response object
res = rq.get(url1)
# check status code 200 = OK
res.status_code
# Out:
# 200

# %% [markdown]
# ## 4. Create our soup object

# %%
soup = bs(res.text,'lxml')
soup.find('title').text
# Out:
# 'Amazon Best Sellers: Best Books'

# %% [markdown]
# ## 5. Find the data:
# * rank
# * title
# * author
# * price
# * rating
# * number_of_reviews

# %%
soup.find("li", "zg-item-immersion").text.strip()
# Out:
# '#1\n\n            The Room Where It Happened: A White House Memoir\n        \nJohn BoltonHardcover$19.50'

# %%
rank_class = "zg-badge-text"
ranks = [x.text.replace("#", "") for x in soup.find_all("span", rank_class)]
len(ranks)
# Out:
# 50

# %%
titles_class = "zg-item"
titles = [x.a.text.strip() for x in soup.find_all("span", titles_class)]
len(titles)
# Out:
# 50

# %%
blacklist = ["Paperback", "Hardcover", "Board book", "Mass Market Paperback"]
author_class = "a-row a-size-small"
authors = [x.text for x in soup.find_all("div", author_class) if x.text not in blacklist]
len(authors)
# Out:
# 50

# %%
price_class = "p13n-sc-price"
prices = [x.text.replace("$", "") for x in soup.find_all("span", price_class)]
len(prices)
# Out:
# 50

# %%
ratings_class = "zg-item"
pattern = r"(\d.\d)\sout"
ratings = [''.join(re.findall(pattern ,x.text)) for x in soup.find_all("span", ratings_class)]
len(ratings)
# Out:
# 50

# %%
reviews_class2 = "zg-item"
pattern = r"stars\s+(\d+\W\d+ | \d+)"
n_reviews = ["".join(re.findall(pattern, x.text.strip().replace("\n", " "))).strip() for x in soup.find_all("span", reviews_class2)]
len(n_reviews)
# Out:
# 50

# %% [markdown]
# ## 6. Create the Data Frame object

# %%
data = pd.DataFrame({"rank": ranks, "title": titles, "author": authors, "price": prices, "rating": ratings, "reviews": n_reviews})

data.replace("", 0)
# Out:
#    rank                                              title  \
# 0     1   The Room Where It Happened: A White House Memoir
# 1     2  I'm Your Emotional Support Animal: Navigating ...
# 2     3                            How to Be an Antiracist
# 3     4  White Fragility: Why It's So Hard for White Pe...
# 4     5  Too Much and Never Enough: How My Family Creat...
# 5     6  Stamped from the Beginning: The Definitive His...
# 6     7                     So You Want to Talk About Race
# 7     8  Countdown 1945: The Extraordinary Story of the...
# 8     9                            Where the Crawdads Sing
# 9    10                          Deacon King Kong: A Novel
# 10   11                                  I Love You, Daddy
# 11   12  The Color of Law: A Forgotten History of How O...
# 12   13  The Ballad of Songbirds and Snakes (A Hunger G...
# 26            Celeste Ng  10.20    4.4  10,827
# 27      Ta-Nehisi Coates  15.48    4.6   5,631
# 28          Sharon Jones   8.40    4.7   2,216
# 29       Jeanine Cummins  16.79    4.5   3,747
# 30           Steve Benen  26.09    5.0       3
# 31            Eric Carle   7.43    4.8     676
# 32                 Ph.D.   5.39    4.7   1,292
# 33          Gin Stephens  15.29    5.0      10
# 34           Lisa Jewell   8.79    4.5   6,078
# 35       Anthony William  20.99    4.6     382
# 36          Sean Hannity  21.49      0       0
# 37            Elias Hill   5.99    4.4   2,351
# 38          Brit Bennett  16.81    4.6      75
# 39          Jimmy Fallon   5.00    4.4   3,506
# 40            Mo Willems   5.24    4.8   2,361
# 41          Rick Riordan  21.00    4.8   5,151
# 42       Bill Martin Jr.   5.67    4.9   7,458
# 43          P.D. Eastman   3.82    4.7   2,856
# 44          John Grisham  17.37    4.1   1,309
# 45         Giles Andreae   5.00    4.8   7,575
# 46       Don Miguel Ruiz   6.48    4.6  11,559
# 47             Dr. Seuss   3.82    4.8   1,219
# 48           Mary Jordan  18.52    3.3       8
# 49            Lucy Foley  16.79    4.2     227

# %% [markdown]
# ## 7. Export csv file

# %%
data.to_csv("../data/amazon.csv" ,index=False)

# %%
pd.read_csv("../data/amazon.csv")
# Out:
#     rank                                              title  \
# 0      1   The Room Where It Happened: A White House Memoir
# 1      2  I'm Your Emotional Support Animal: Navigating ...
# 2      3                            How to Be an Antiracist
# 3      4  White Fragility: Why It's So Hard for White Pe...
# 4      5  Too Much and Never Enough: How My Family Creat...
# 5      6  Stamped from the Beginning: The Definitive His...
# 6      7                     So You Want to Talk About Race
# 7      8  Countdown 1945: The Extraordinary Story of the...
# 8      9                            Where the Crawdads Sing
# 9     10                          Deacon King Kong: A Novel
# 10    11                                  I Love You, Daddy
# 11    12  The Color of Law: A Forgotten History of How O...
# 12    13  The Ballad of Songbirds and Snakes (A Hunger G...
# 13    14  Skinnytaste Meal Prep: Healthy Make-Ahead Meal...
# 14    15                                            Untamed
# 15    16                       If Animals Kissed Good Night
# 16    17                Just Me and My Dad (Little Critter)
# 17    18  My First Learn to Write Workbook: Practice for...
# 18    19                                           Becoming
# 19    20  Why Are All the Black Kids Sitting Together in...
# 20    21  School Zone - Big Preschool Workbook - Ages 4 ...
# 21    22  We're Different, We're the Same (Sesame Street...
# 22    23                        The Very Hungry Caterpillar
# 23    24  The Splendid and the Vile: A Saga of Churchill...
# 24    25                                         28 Summers
# 25    26      Just Mercy: A Story of Justice and Redemption
# 26    27                   Little Fires Everywhere: A Novel
# 27    28                           Between the World and Me
# 28    29                                 Burn After Writing
# 29    30         American Dirt (Oprah's Book Club): A Novel
# 30    31  The Impostors: How Republicans Quit Governing ...
# 31    32  I Love Dad with The Very Hungry Caterpillar (T...
# 32    33  Human Body Activity Book for Kids: Hands-On Fu...
# 33    34  Fast. Feast. Repeat.: The Comprehensive Guide ...
# 34    35                         Then She Was Gone: A Novel
# 35    36  Medical Medium Cleanse to Heal: Healing Plans ...
# 36    37  Live Free Or Die: America (and the World) on t...
